# %%
import pandas as pd

# %%
test_default = pd.read_csv('data/irs_county_2016.csv')
test_default.head()
# Out:
#    STATEFIPS STATE  COUNTYFIPS COUNTYNAME  agi_stub      N1   mars1   MARS2  \
# 0          1    AL           0    Alabama         1   26450   14680    9740
# 1          1    AL           0    Alabama         2  285760  217880   25170
# 2          1    AL           0    Alabama         3  529780  259680   80320
# 3          1    AL           0    Alabama         4  495750  211100  141800
# 4          1    AL           0    Alabama         5  263130   82330  137610
#
#     MARS4    PREP  ...  N10300   A10300  N85530  A85530  N85300  A85300  \
# 0     680   17780  ...    4300     9256      70      57       0       0
# 1   39740  143390  ...   70050    40569       0       0       0       0
# 2  181410  297440  ...  297770   290358       0       0       0       0
# 3  127420  272030  ...  397940   983800      40      22       0       0
# 4   35760  154540  ...  252940  1346083      20      27       0       0
#
#    N11901  A11901  N11902   A11902
# 0    2590    3685   11510    35079
# ...

# %%
test_default.drop(columns = ['STATEFIPS'])
# Out:
#       STATE  COUNTYFIPS       COUNTYNAME  agi_stub      N1   mars1   MARS2  \
# 0        AL           0          Alabama         1   26450   14680    9740
# 1        AL           0          Alabama         2  285760  217880   25170
# 2        AL           0          Alabama         3  529780  259680   80320
# 3        AL           0          Alabama         4  495750  211100  141800
# 4        AL           0          Alabama         5  263130   82330  137610
# 5        AL           0          Alabama         6  167080   29240  124090
# 6        AL           0          Alabama         7  216280   21250  186850
# 7        AL           0          Alabama         8   59310    4250   53160
# 8        AL           1   Autauga County         1     210     110      90
# 9        AL           1   Autauga County         2    3210    2570     240
# 10       AL           1   Autauga County         3    5410    2830     780
# ...
